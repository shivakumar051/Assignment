# %% [markdown]
# <a href="https://colab.research.google.com/github/shivakumar051/Assignment/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TASK-1: Implement a Regression using Single-Layer Neural Network. Take two set x and y and trained the model to find out the correct y=function of x. Already we discussed these in our previous lectures.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x = np.array([1, 2, 3, 4, 5], dtype=float)
y = np.array([1, 4, 9, 16, 25], dtype=float)  # Example function y = x^2

# %%
model = Sequential([
    Dense(units=1, input_shape=[1])
])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
model.fit(x, y, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 737ms/step - loss: 112.3029
# Epoch 2/500
# 1/1 [==============================] - 0s 11ms/step - loss: 71.1241
# Epoch 3/500
# 1/1 [==============================] - 0s 15ms/step - loss: 47.0967
# Epoch 4/500
# 1/1 [==============================] - 0s 12ms/step - loss: 33.0645
# Epoch 5/500
# 1/1 [==============================] - 0s 12ms/step - loss: 24.8572
# Epoch 6/500
# 1/1 [==============================] - 0s 13ms/step - loss: 20.0445
# Epoch 7/500
# 1/1 [==============================] - 0s 20ms/step - loss: 17.2103
# Epoch 8/500
# 1/1 [==============================] - 0s 13ms/step - loss: 15.5292
# Epoch 9/500
# 1/1 [==============================] - 0s 15ms/step - loss: 14.5203
# Epoch 10/500
# 1/1 [==============================] - 0s 11ms/step - loss: 13.9033
# Epoch 11/500
# 1/1 [==============================] - 0s 14ms/step - loss: 13.5149
# Epoch 12/500
# ...

# %%
print(model.predict([6.0]))
# Out:
# 1/1 [==============================] - 0s 114ms/step
# [[28.054157]]

# %% [markdown]
# TASK-2:  Multiclass Classification using Dense Neural Network. Please use the dataset available at the given link below
#
# https://github.com/zalandoresearch/fashion-mnist

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.fashion_mnist.load_data()

# Normalize the data
train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.5068 - accuracy: 0.8211
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3731 - accuracy: 0.8659
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3403 - accuracy: 0.8759
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3140 - accuracy: 0.8842
# Epoch 5/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2987 - accuracy: 0.8894
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2826 - accuracy: 0.8960
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2693 - accuracy: 0.9005
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2592 - accuracy: 0.9035
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2500 - accuracy: 0.9071
# Epoch 10/10
# ...

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_acc}')
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3467 - accuracy: 0.8809
# Test accuracy: 0.8809000253677368

# %%
predictions = model.predict(test_images)

# Example: Predict the first image in the test set
print(np.argmax(predictions[0]))
# Out:
# 313/313 [==============================] - 1s 2ms/step
# 9
